# %% [markdown]
# # Bagging -vs- random- forest

# %%
import numpy as np 
import pandas as pd

from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.tree import plot_tree

import matplotlib.pyplot as plt

# %%
X, y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=10)

# %%
df = pd.DataFrame(X, columns=['cols1','cols','cols3','cols4','cols5'])
df['target'] = y

# %%
df.shape
# Out:
# (100, 6)

# %%
df.head()
# Out:
#       cols1      cols     cols3     cols4     cols5  target
# 0  2.733245 -0.697804 -0.434862 -2.850547 -0.986484       0
# 1  2.011446 -1.946186  2.126069  0.937073 -1.645470       0
# 2  2.303794  0.009657  2.014710 -0.607913  0.542456       1
# 3  0.256479  1.456718  3.162312  3.757930 -2.884517       1
# 4  0.175084  0.125439  1.153805  3.185146  0.148022       1

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %% [markdown]
# # Random forest

# %%
rf  = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[4])
plt.show()
